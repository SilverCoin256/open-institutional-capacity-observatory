# %% [markdown]
# # Metric Examples
#
# Small examples for QAI, authorization quality, and procedural capacity.

# %%
from oico.metrics.qai import queue_acceleration_index
from oico.models.authorization import intervention_scenarios
from oico.models.procedural_capacity import procedural_failure_risk

qai = queue_acceleration_index(1108300, 975977, 195145)
assert round(qai, 3) == 0.678
print('QAI example:', round(qai, 3))
print('Authorization scenarios:', intervention_scenarios()[:2])
print('Procedural risk:', round(procedural_failure_risk(140, 100, 0.5, 1.0), 3))
