# %% [markdown]
# # Five-Minute Demo
#
# A short path for conference demos or lab meetings.

# %%
from oico.metrics.qai import queue_acceleration_index
from oico.benchmarks import run_all_benchmarks

print('QAI example:', round(queue_acceleration_index(1391361, 1108300, 277076), 3))
results = run_all_benchmarks()
for result in results:
    print(result['task'], '-', result['evaluation_metric'])
print('Caveat: v1 baselines are for reproducibility and teaching, not a mature leaderboard.')
